# %%
import pandas as pd
from rdkit import Chem
from rdkit.ML.Descriptors.Descriptors import DescriptorCalculator
from rdkit.ML.Descriptors.MoleculeDescriptors import MolecularDescriptorCalculator
import numpy as np
import catboost
from tqdm import tqdm
from sklearn import metrics
from sklearn.model_selection import cross_val_score, KFold, train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split, RandomizedSearchCV
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error
from statistics import mean, stdev
from platform import python_version
print(python_version())
# Out:
# 3.10.9

# %%
def read_data(file_name):
    df = pd.read_excel(file_name)
    df['SMILES'] = df['SMILES'].replace('>>', '.', regex=True)
    return df

# %%
def calculate_descriptors(df):
    descriptor_names = list(Chem.rdMolDescriptors.Properties.GetAvailableProperties())
    descriptor_names.remove('exactmw')
    for name in tqdm(descriptor_names):
        df[name] = df['SMILES'].apply(lambda x: descriptor(name, x))
    return df

# %%
def descriptor(descriptor:str, smi:str)->float:
    get_descriptors = Chem.rdMolDescriptors.Properties([descriptor])
    try:
        return get_descriptors.ComputeProperties(Chem.MolFromSmiles(smi))[0]
    except:
        return None

# %%
def filter_descriptors(data, threshold=0.9):
    descriptors = data.drop(["SMILES", 'yield', 'Ind'], axis=1)
    corr = descriptors.copy().corr()
    for index in corr.index:
        corr.loc[index, index] = 0
    descriptors_not_correlated = corr[(corr <= threshold)].dropna().index.tolist()
    print('Number of descriptors:', len(descriptors_not_correlated) - 1)
    return data[descriptors_not_correlated], data['yield']

# %%
def random_forest_regression(X, y):
    rmse_scores = []
    r2_scores = []
    for i in range(10):
        X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=i)
        model = RandomForestRegressor(n_estimators=800, max_depth=8)
        model.fit(X_train, y_train)
        y_pred = model.predict(X_test)
        rmse = np.sqrt(mean_squared_error(y_test, y_pred))
        rmse_scores.append(rmse)
        r2 = r2_score(y_test, y_pred)
        r2_scores.append(r2)
        #print(f"Iteration {i}: RMSE = {rmse:.3f}, R^2  = {r2:.3f}")
    print("\nAverage performance of test set at 10 split")
    print("Metric\tavg\tstdev")
    print("R^2\t%.2f\t%.2f" % (mean(r2_scores), stdev(r2_scores)))
    print("RMSE\t%.2f\t%.2f" % (mean(rmse_scores), stdev(rmse_scores)))

# %%
def statistics_for_the_training_set_with_5CV_RFR(X, y):
    r2_scores = []
    rmse_scores = []
    for i in range(10):
        X_tr, X_t, y_tr, y_t = train_test_split(X, y, test_size=0.2, random_state=i)
        X_tr.reset_index(drop=True , inplace=True)
        y_tr.reset_index(drop=True , inplace=True)
        cv = KFold(n_splits=5, shuffle=True, random_state=1)
        y_pred, y_true = [], []
        for train_index, test_index in cv.split(X_tr):
            X_train = X_tr.loc[train_index].values
            X_test = X_tr.loc[test_index].values
            y_train = y_tr.loc[train_index].values
            y_test = y_tr.loc[test_index].values
    
            model = RandomForestRegressor(n_estimators=800, max_depth=8)
            model.fit(X_train, y_train)
            y_pred.extend(model.predict(X_test))
            y_true.extend(y_test)

        r2_scores.append(metrics.r2_score(y_true, y_pred))
        rmse_scores.append(metrics.mean_squared_error(y_true, y_pred, squared=False))
      
    print("\nAverage performance of 5CV")
    print("Metric\tavg\tstdev")
    print("R^2\t%.2f\t%.2f" % (mean(r2_scores), stdev(r2_scores)))
    print("RMSE\t%.2f\t%.2f" % (mean(rmse_scores), stdev(rmse_scores)))

# %%
def catboost_regression(X, y):
    rmse_scores = []
    r2_scores = []
    for i in range(10):
        X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=i)
        model = catboost.CatBoostRegressor(learning_rate=0.02, l2_leaf_reg=9.5, depth=7, silent=True)
        model.fit(X_train, y_train)
        y_pred = model.predict(X_test)
        rmse = np.sqrt(mean_squared_error(y_test, y_pred))
        rmse_scores.append(rmse)
        r2 = r2_score(y_test, y_pred)
        r2_scores.append(r2)
        #print(f"Iteration {i}: RMSE = {rmse:.3f}, R2 = {r2:.3f}")
    print("\nAverage performance of test set at 10 split")
    print("Metric\tavg\tstdev")
    print("R^2\t%.2f\t%.2f" % (mean(r2_scores), stdev(r2_scores)))
    print("RMSE\t%.2f\t%.2f" % (mean(rmse_scores), stdev(rmse_scores)))

# %%
def statistics_for_the_training_set_with_5CV_catBoost(X, y):
    r2_scores = []
    rmse_scores = []
    for i in range(10):
        X_tr, X_t, y_tr, y_t = train_test_split(X, y, test_size=0.2, random_state=i)
        X_tr.reset_index(drop=True , inplace=True)
        y_tr.reset_index(drop=True , inplace=True)
        cv = KFold(n_splits=5, shuffle=True, random_state=1)
        y_pred, y_true = [], []
        for train_index, test_index in cv.split(X_tr):
            X_train = X_tr.loc[train_index].values
            X_test = X_tr.loc[test_index].values
            y_train = y_tr.loc[train_index].values
            y_test = y_tr.loc[test_index].values
    
            model = catboost.CatBoostRegressor(learning_rate=0.02, l2_leaf_reg=9.5, depth=7, silent=True)
            model.fit(X_train, y_train)
            y_pred.extend(model.predict(X_test))
            y_true.extend(y_test)

        r2_scores.append(metrics.r2_score(y_true, y_pred))
        rmse_scores.append(metrics.mean_squared_error(y_true, y_pred, squared=False))
      
    print("\nAverage performance of 5CV")
    print("Metric\tavg\tstdev")
    print("R^2\t%.2f\t%.2f" % (mean(r2_scores), stdev(r2_scores)))
    print("RMSE\t%.2f\t%.2f" % (mean(rmse_scores), stdev(rmse_scores)))

# %%
def product_strategy_random_forest(data, X, y):
    unique_inds = data['Ind'].unique()
    rmse_scores = []
    r2_scores = []
    for i in range(10):
        ind_train, ind_test = train_test_split(unique_inds, test_size=0.20, random_state=i)
        train_indices = data[data['Ind'].isin(ind_train)].index
        test_indices = data[data['Ind'].isin(ind_test)].index
        x_train, y_train = X.loc[train_indices].values, y.loc[train_indices].values
        x_test, y_test = X.loc[test_indices].values, y.loc[test_indices].values
        model = RandomForestRegressor(n_estimators=800, max_depth=8)
        model.fit(x_train, y_train)
        y_pred = model.predict(x_test)
        rmse = np.sqrt(mean_squared_error(y_test, y_pred))
        rmse_scores.append(rmse)
        r2 = r2_score(y_test, y_pred)
        r2_scores.append(r2)
        #print(f"Iteration {i}: RMSE = {rmse:.3f}, R2 = {r2:.3f}")
    print("\nAverage performance of test set at 10 split")
    print("Metric\tavg\tstdev")
    print("R^2\t%.2f\t%.2f" % (mean(r2_scores), stdev(r2_scores)))
    print("RMSE\t%.2f\t%.2f" % (mean(rmse_scores), stdev(rmse_scores)))

# %%
def product_statistics_for_the_training_set_with_5CV_RFR(data, X, y):
    unique_inds = data['Ind'].unique()
    ind_train, ind_test = train_test_split(unique_inds, test_size=0.2, random_state=1)

    train_indices = data[data['Ind'].isin(ind_train)].index
    test_indices = data[data['Ind'].isin(ind_test)].index

    x_train, y_train = X.loc[train_indices].values, y.loc[train_indices].values
    x_test, y_test = X.loc[test_indices].values, y.loc[test_indices].values

    kf = KFold(n_splits=5, shuffle=True, random_state=1)
    rmse_scores = []
    r2_scores = []

    for train_index, test_index in kf.split(x_train):
        x_train_fold, x_val_fold = x_train[train_index], x_train[test_index]
        y_train_fold, y_val_fold = y_train[train_index], y_train[test_index]
    
        model = RandomForestRegressor(n_estimators=800, max_depth=8, verbose=0)  # Use verbose=0 instead of silent=True
        model.fit(x_train_fold, y_train_fold)
        y_pred = model.predict(x_val_fold)
    
        rmse = np.sqrt(mean_squared_error(y_val_fold, y_pred))
        rmse_scores.append(rmse)
    
        r2 = r2_score(y_val_fold, y_pred)
        r2_scores.append(r2)
    
    print('R^2 = ', round(np.mean(r2_scores), 2))
    print('RMSE = ', round(np.mean(rmse_scores), 2))

# %%
def product_strategy_catboost(data, X, y):
    unique_inds = data['Ind'].unique()
    rmse_scores = []
    r2_scores = []
    for i in range(10):
        ind_train, ind_test = train_test_split(unique_inds, test_size=0.20, random_state=i)
        train_indices = data[data['Ind'].isin(ind_train)].index
        test_indices = data[data['Ind'].isin(ind_test)].index
        x_train, y_train = X.loc[train_indices].values, y.loc[train_indices].values
        x_test, y_test = X.loc[test_indices].values, y.loc[test_indices].values
        model = catboost.CatBoostRegressor(learning_rate=0.02, l2_leaf_reg=9.5, depth=7, silent=True)
        model.fit(x_train, y_train)
        y_pred = model.predict(x_test)
        rmse = np.sqrt(mean_squared_error(y_test, y_pred))
        rmse_scores.append(rmse)
        r2 = r2_score(y_test, y_pred)
        r2_scores.append(r2)
        #print(f"Iteration {i}: RMSE = {rmse:.3f}, R2 = {r2:.3f}")
    print("\nAverage performance of test set at 10 split")
    print("Metric\tavg\tstdev")
    print("R^2\t%.2f\t%.2f" % (mean(r2_scores), stdev(r2_scores)))
    print("RMSE\t%.2f\t%.2f" % (mean(rmse_scores), stdev(rmse_scores)))

# %%
def product_statistics_for_the_training_set_with_5CV_catBoost(data,X, y):
    unique_inds = data['Ind'].unique()
    ind_train, ind_test = train_test_split(unique_inds, test_size=0.2, random_state=1)

    train_indices = data[data['Ind'].isin(ind_train)].index
    test_indices = data[data['Ind'].isin(ind_test)].index

    x_train, y_train = X.loc[train_indices].values, y.loc[train_indices].values
    x_test, y_test = X.loc[test_indices].values, y.loc[test_indices].values

    kf = KFold(n_splits=5, shuffle=True, random_state=1)
    rmse_scores = []
    r2_scores = []

    for train_index, test_index in kf.split(x_train):
        x_train_fold, x_val_fold = x_train[train_index], x_train[test_index]
        y_train_fold, y_val_fold = y_train[train_index], y_train[test_index]
    
        model = catboost.CatBoostRegressor(learning_rate=0.02, l2_leaf_reg=9.5, depth=7, silent=True)
        model.fit(x_train_fold, y_train_fold)
        y_pred = model.predict(x_val_fold)
    
        rmse = np.sqrt(mean_squared_error(y_val_fold, y_pred))
        rmse_scores.append(rmse)
    
        r2 = r2_score(y_val_fold, y_pred)
        r2_scores.append(r2)
    
    print('R^2 = ', round(np.mean(r2_scores), 2))
    print('RMSE = ', round(np.mean(rmse_scores), 2))

# %%
if __name__ == "__main__":
    df = read_data("Condensation_reactions.xls")
    df = calculate_descriptors(df)
    data = df.dropna()
    data.reset_index(drop=True, inplace=True)
    X, y = filter_descriptors(data)

    # The "reaction" strategy
    print("Random Forest Regression:")
    random_forest_regression(X, y)

    print("\nStatistics for the training set with 5CV RFR:")
    statistics_for_the_training_set_with_5CV_RFR(X, y)
    
    print("\nCatBoost Regression:")
    catboost_regression(X, y)
    
    print("\nStatistics for the training set with 5CV catBoost:")
    statistics_for_the_training_set_with_5CV_catBoost(X, y)

    # The "product" strategy
    print("\nProduct Strategy with Random Forest Regression:")
    product_strategy_random_forest(data, X, y)

    print("\nProduct Strategy with Statistics for the training set with 5CV RFR:")
    product_statistics_for_the_training_set_with_5CV_RFR(data,X, y)
    
    print("\nProduct Strategy with CatBoost Regression:")
    product_strategy_catboost(data, X, y)
    
    print("\nProduct Strategy with Statistics for the training set with 5CV catBoost:")
    product_statistics_for_the_training_set_with_5CV_catBoost(data, X, y)
# Out:
#   0%|          | 0/42 [00:00<?, ?it/s][15:30:51] Explicit valence for atom # 26 H, 2, is greater than permitted
# [15:30:51] Explicit valence for atom # 26 H, 2, is greater than permitted
# [15:30:51] Explicit valence for atom # 0 O, 3, is greater than permitted
# [15:30:51] Explicit valence for atom # 10 O, 3, is greater than permitted
#   2%|▏         | 1/42 [00:00<00:16,  2.54it/s][15:30:51] Explicit valence for atom # 26 H, 2, is greater than permitted
# [15:30:51] Explicit valence for atom # 26 H, 2, is greater than permitted
# [15:30:51] Explicit valence for atom # 0 O, 3, is greater than permitted
# [15:30:52] Explicit valence for atom # 10 O, 3, is greater than permitted
#   5%|▍         | 2/42 [00:00<00:15,  2.58it/s][15:30:52] Explicit valence for atom # 26 H, 2, is greater than permitted
# [15:30:52] Explicit valence for atom # 26 H, 2, is greater than permitted
# [15:30:52] Explicit valence for atom # 0 O, 3, is greater than permitted
# [15:30:52] Explicit valence for atom # 10 O, 3, is greater than permitted
#   7%|▋         | 3/42 [00:01<00:14,  2.63it/s][15:30:52] Explicit valence for atom # 26 H, 2, is greater than permitted
# [15:30:52] Explicit valence for atom # 26 H, 2, is greater than permitted
# [15:30:52] Explicit valence for atom # 0 O, 3, is greater than permitted
# [15:30:52] Explicit valence for atom # 10 O, 3, is greater than permitted
#  10%|▉         | 4/42 [00:01<00:16,  2.37it/s][15:30:53] Explicit valence for atom # 26 H, 2, is greater than permitted
# [15:30:53] Explicit valence for atom # 26 H, 2, is greater than permitted
# [15:30:53] Explicit valence for atom # 0 O, 3, is greater than permitted
# [15:30:53] Explicit valence for atom # 10 O, 3, is greater than permitted
#  12%|█▏        | 5/42 [00:02<00:15,  2.45it/s][15:30:53] Explicit valence for atom # 26 H, 2, is greater than permitted
# [15:30:53] Explicit valence for atom # 26 H, 2, is greater than permitted
# [15:30:53] Explicit valence for atom # 0 O, 3, is greater than permitted
# [15:30:53] Explicit valence for atom # 10 O, 3, is greater than permitted
#  14%|█▍        | 6/42 [00:02<00:14,  2.42it/s][15:30:53] Explicit valence for atom # 26 H, 2, is greater than permitted
# [15:30:53] Explicit valence for atom # 26 H, 2, is greater than permitted
# [15:30:54] Explicit valence for atom # 0 O, 3, is greater than permitted
# [15:30:54] Explicit valence for atom # 10 O, 3, is greater than permitted
#  17%|█▋        | 7/42 [00:02<00:14,  2.47it/s][15:30:54] Explicit valence for atom # 26 H, 2, is greater than permitted
# [15:30:54] Explicit valence for atom # 26 H, 2, is greater than permitted
# [15:30:54] Explicit valence for atom # 0 O, 3, is greater than permitted
# [15:30:54] Explicit valence for atom # 10 O, 3, is greater than permitted
#  19%|█▉        | 8/42 [00:03<00:13,  2.52it/s][15:30:54] Explicit valence for atom # 26 H, 2, is greater than permitted
# [15:30:54] Explicit valence for atom # 26 H, 2, is greater than permitted
# [15:30:54] Explicit valence for atom # 0 O, 3, is greater than permitted
# [15:30:54] Explicit valence for atom # 10 O, 3, is greater than permitted
#  21%|██▏       | 9/42 [00:03<00:12,  2.54it/s][15:30:54] Explicit valence for atom # 26 H, 2, is greater than permitted
# [15:30:55] Explicit valence for atom # 26 H, 2, is greater than permitted
# [15:30:55] Explicit valence for atom # 0 O, 3, is greater than permitted
# [15:30:55] Explicit valence for atom # 10 O, 3, is greater than permitted
#  24%|██▍       | 10/42 [00:03<00:12,  2.57it/s][15:30:55] Explicit valence for atom # 26 H, 2, is greater than permitted
# [15:30:55] Explicit valence for atom # 26 H, 2, is greater than permitted
# [15:30:55] Explicit valence for atom # 0 O, 3, is greater than permitted
# [15:30:55] Explicit valence for atom # 10 O, 3, is greater than permitted
#  26%|██▌       | 11/42 [00:04<00:11,  2.61it/s][15:30:55] Explicit valence for atom # 26 H, 2, is greater than permitted
# [15:30:55] Explicit valence for atom # 26 H, 2, is greater than permitted
# [15:30:55] Explicit valence for atom # 0 O, 3, is greater than permitted
# [15:30:55] Explicit valence for atom # 10 O, 3, is greater than permitted
#  29%|██▊       | 12/42 [00:04<00:11,  2.63it/s][15:30:56] Explicit valence for atom # 26 H, 2, is greater than permitted
# [15:30:56] Explicit valence for atom # 26 H, 2, is greater than permitted
# [15:30:56] Explicit valence for atom # 0 O, 3, is greater than permitted
# [15:30:56] Explicit valence for atom # 10 O, 3, is greater than permitted
#  31%|███       | 13/42 [00:05<00:10,  2.65it/s][15:30:56] Explicit valence for atom # 26 H, 2, is greater than permitted
# [15:30:56] Explicit valence for atom # 26 H, 2, is greater than permitted
# [15:30:56] Explicit valence for atom # 0 O, 3, is greater than permitted
# [15:30:56] Explicit valence for atom # 10 O, 3, is greater than permitted
#  33%|███▎      | 14/42 [00:05<00:10,  2.65it/s][15:30:56] Explicit valence for atom # 26 H, 2, is greater than permitted
# [15:30:56] Explicit valence for atom # 26 H, 2, is greater than permitted
# [15:30:57] Explicit valence for atom # 0 O, 3, is greater than permitted
# [15:30:57] Explicit valence for atom # 10 O, 3, is greater than permitted
#  36%|███▌      | 15/42 [00:05<00:10,  2.66it/s][15:30:57] Explicit valence for atom # 26 H, 2, is greater than permitted
# [15:30:57] Explicit valence for atom # 26 H, 2, is greater than permitted
# [15:30:57] Explicit valence for atom # 0 O, 3, is greater than permitted
# [15:30:57] Explicit valence for atom # 10 O, 3, is greater than permitted
#  38%|███▊      | 16/42 [00:06<00:09,  2.67it/s][15:30:57] Explicit valence for atom # 26 H, 2, is greater than permitted
# [15:30:57] Explicit valence for atom # 26 H, 2, is greater than permitted
# [15:30:57] Explicit valence for atom # 0 O, 3, is greater than permitted
# [15:30:57] Explicit valence for atom # 10 O, 3, is greater than permitted
#  40%|████      | 17/42 [00:06<00:09,  2.66it/s][15:30:57] Explicit valence for atom # 26 H, 2, is greater than permitted
# [15:30:58] Explicit valence for atom # 26 H, 2, is greater than permitted
# [15:30:58] Explicit valence for atom # 0 O, 3, is greater than permitted
# [15:30:58] Explicit valence for atom # 10 O, 3, is greater than permitted
#  43%|████▎     | 18/42 [00:06<00:09,  2.66it/s][15:30:58] Explicit valence for atom # 26 H, 2, is greater than permitted
# [15:30:58] Explicit valence for atom # 26 H, 2, is greater than permitted
# [15:30:58] Explicit valence for atom # 0 O, 3, is greater than permitted
# [15:30:58] Explicit valence for atom # 10 O, 3, is greater than permitted
#  45%|████▌     | 19/42 [00:07<00:08,  2.65it/s][15:30:58] Explicit valence for atom # 26 H, 2, is greater than permitted
# [15:30:58] Explicit valence for atom # 26 H, 2, is greater than permitted
# [15:30:58] Explicit valence for atom # 0 O, 3, is greater than permitted
# [15:30:59] Explicit valence for atom # 10 O, 3, is greater than permitted
#  48%|████▊     | 20/42 [00:07<00:08,  2.64it/s][15:30:59] Explicit valence for atom # 26 H, 2, is greater than permitted
# [15:30:59] Explicit valence for atom # 26 H, 2, is greater than permitted
# [15:30:59] Explicit valence for atom # 0 O, 3, is greater than permitted
# [15:30:59] Explicit valence for atom # 10 O, 3, is greater than permitted
#  50%|█████     | 21/42 [00:08<00:07,  2.64it/s][15:30:59] Explicit valence for atom # 26 H, 2, is greater than permitted
# [15:30:59] Explicit valence for atom # 26 H, 2, is greater than permitted
# [15:30:59] Explicit valence for atom # 0 O, 3, is greater than permitted
# [15:30:59] Explicit valence for atom # 10 O, 3, is greater than permitted
#  52%|█████▏    | 22/42 [00:08<00:07,  2.64it/s][15:30:59] Explicit valence for atom # 26 H, 2, is greater than permitted
# [15:30:59] Explicit valence for atom # 26 H, 2, is greater than permitted
# [15:31:00] Explicit valence for atom # 0 O, 3, is greater than permitted
# [15:31:00] Explicit valence for atom # 10 O, 3, is greater than permitted
#  55%|█████▍    | 23/42 [00:08<00:07,  2.66it/s][15:31:00] Explicit valence for atom # 26 H, 2, is greater than permitted
# [15:31:00] Explicit valence for atom # 26 H, 2, is greater than permitted
# [15:31:00] Explicit valence for atom # 0 O, 3, is greater than permitted
# [15:31:00] Explicit valence for atom # 10 O, 3, is greater than permitted
#  57%|█████▋    | 24/42 [00:09<00:06,  2.65it/s][15:31:00] Explicit valence for atom # 26 H, 2, is greater than permitted
# [15:31:00] Explicit valence for atom # 26 H, 2, is greater than permitted
# [15:31:00] Explicit valence for atom # 0 O, 3, is greater than permitted
# [15:31:00] Explicit valence for atom # 10 O, 3, is greater than permitted
#  60%|█████▉    | 25/42 [00:09<00:06,  2.64it/s][15:31:01] Explicit valence for atom # 26 H, 2, is greater than permitted
# [15:31:01] Explicit valence for atom # 26 H, 2, is greater than permitted
# [15:31:01] Explicit valence for atom # 0 O, 3, is greater than permitted
# [15:31:01] Explicit valence for atom # 10 O, 3, is greater than permitted
#  62%|██████▏   | 26/42 [00:10<00:09,  1.70it/s][15:31:02] Explicit valence for atom # 26 H, 2, is greater than permitted
# [15:31:02] Explicit valence for atom # 26 H, 2, is greater than permitted
# [15:31:02] Explicit valence for atom # 0 O, 3, is greater than permitted
# [15:31:03] Explicit valence for atom # 10 O, 3, is greater than permitted
#  64%|██████▍   | 27/42 [00:11<00:10,  1.36it/s][15:31:03] Explicit valence for atom # 26 H, 2, is greater than permitted
# [15:31:03] Explicit valence for atom # 26 H, 2, is greater than permitted
# [15:31:03] Explicit valence for atom # 0 O, 3, is greater than permitted
# [15:31:03] Explicit valence for atom # 10 O, 3, is greater than permitted
#  67%|██████▋   | 28/42 [00:12<00:08,  1.60it/s][15:31:03] Explicit valence for atom # 26 H, 2, is greater than permitted
# [15:31:03] Explicit valence for atom # 26 H, 2, is greater than permitted
# [15:31:03] Explicit valence for atom # 0 O, 3, is greater than permitted
# [15:31:03] Explicit valence for atom # 10 O, 3, is greater than permitted
#  69%|██████▉   | 29/42 [00:12<00:07,  1.78it/s][15:31:04] Explicit valence for atom # 26 H, 2, is greater than permitted
# [15:31:04] Explicit valence for atom # 26 H, 2, is greater than permitted
# [15:31:04] Explicit valence for atom # 0 O, 3, is greater than permitted
# [15:31:04] Explicit valence for atom # 10 O, 3, is greater than permitted
#  71%|███████▏  | 30/42 [00:13<00:06,  1.72it/s][15:31:04] Explicit valence for atom # 26 H, 2, is greater than permitted
# [15:31:04] Explicit valence for atom # 26 H, 2, is greater than permitted
# [15:31:04] Explicit valence for atom # 0 O, 3, is greater than permitted
# [15:31:05] Explicit valence for atom # 10 O, 3, is greater than permitted
#  74%|███████▍  | 31/42 [00:13<00:06,  1.68it/s][15:31:05] Explicit valence for atom # 26 H, 2, is greater than permitted
# [15:31:05] Explicit valence for atom # 26 H, 2, is greater than permitted
# [15:31:05] Explicit valence for atom # 0 O, 3, is greater than permitted
# [15:31:05] Explicit valence for atom # 10 O, 3, is greater than permitted
#  76%|███████▌  | 32/42 [00:14<00:06,  1.55it/s][15:31:05] Explicit valence for atom # 26 H, 2, is greater than permitted
# [15:31:06] Explicit valence for atom # 26 H, 2, is greater than permitted
# [15:31:06] Explicit valence for atom # 0 O, 3, is greater than permitted
# [15:31:06] Explicit valence for atom # 10 O, 3, is greater than permitted
#  79%|███████▊  | 33/42 [00:14<00:05,  1.77it/s][15:31:06] Explicit valence for atom # 26 H, 2, is greater than permitted
# [15:31:06] Explicit valence for atom # 26 H, 2, is greater than permitted
# [15:31:06] Explicit valence for atom # 0 O, 3, is greater than permitted
# [15:31:06] Explicit valence for atom # 10 O, 3, is greater than permitted
#  81%|████████  | 34/42 [00:15<00:04,  1.97it/s][15:31:06] Explicit valence for atom # 26 H, 2, is greater than permitted
# [15:31:06] Explicit valence for atom # 26 H, 2, is greater than permitted
# [15:31:07] Explicit valence for atom # 0 O, 3, is greater than permitted
# [15:31:07] Explicit valence for atom # 10 O, 3, is greater than permitted
#  83%|████████▎ | 35/42 [00:15<00:03,  1.84it/s][15:31:07] Explicit valence for atom # 26 H, 2, is greater than permitted
# [15:31:07] Explicit valence for atom # 26 H, 2, is greater than permitted
# [15:31:07] Explicit valence for atom # 0 O, 3, is greater than permitted
# [15:31:07] Explicit valence for atom # 10 O, 3, is greater than permitted
#  86%|████████▌ | 36/42 [00:16<00:03,  1.74it/s][15:31:08] Explicit valence for atom # 26 H, 2, is greater than permitted
# [15:31:08] Explicit valence for atom # 26 H, 2, is greater than permitted
# [15:31:08] Explicit valence for atom # 0 O, 3, is greater than permitted
# [15:31:08] Explicit valence for atom # 10 O, 3, is greater than permitted
#  88%|████████▊ | 37/42 [00:17<00:03,  1.55it/s][15:31:08] Explicit valence for atom # 26 H, 2, is greater than permitted
# [15:31:08] Explicit valence for atom # 26 H, 2, is greater than permitted
# [15:31:09] Explicit valence for atom # 0 O, 3, is greater than permitted
# [15:31:09] Explicit valence for atom # 10 O, 3, is greater than permitted
#  90%|█████████ | 38/42 [00:17<00:02,  1.76it/s][15:31:09] Explicit valence for atom # 26 H, 2, is greater than permitted
# [15:31:09] Explicit valence for atom # 26 H, 2, is greater than permitted
# [15:31:09] Explicit valence for atom # 0 O, 3, is greater than permitted
# [15:31:09] Explicit valence for atom # 10 O, 3, is greater than permitted
#  93%|█████████▎| 39/42 [00:18<00:01,  1.94it/s][15:31:09] Explicit valence for atom # 26 H, 2, is greater than permitted
# [15:31:09] Explicit valence for atom # 26 H, 2, is greater than permitted
# [15:31:09] Explicit valence for atom # 0 O, 3, is greater than permitted
# [15:31:10] Explicit valence for atom # 10 O, 3, is greater than permitted
#  95%|█████████▌| 40/42 [00:18<00:01,  1.88it/s][15:31:10] Explicit valence for atom # 26 H, 2, is greater than permitted
# [15:31:10] Explicit valence for atom # 26 H, 2, is greater than permitted
# [15:31:10] Explicit valence for atom # 0 O, 3, is greater than permitted
# [15:31:10] Explicit valence for atom # 10 O, 3, is greater than permitted
#  98%|█████████▊| 41/42 [00:19<00:00,  1.76it/s][15:31:10] Explicit valence for atom # 26 H, 2, is greater than permitted
# [15:31:11] Explicit valence for atom # 26 H, 2, is greater than permitted
# [15:31:11] Explicit valence for atom # 0 O, 3, is greater than permitted
# [15:31:11] Explicit valence for atom # 10 O, 3, is greater than permitted
# 100%|██████████| 42/42 [00:19<00:00,  2.10it/s]
# Number of descriptors: 13
# Random Forest Regression:
#
# Average performance of test set at 10 split
# Metric	avg	stdev
# R^2	0.56	0.05
# RMSE	13.99	0.73
#
# Statistics for the training set with 5CV RFR:
#
# Average performance of 5CV
# Metric	avg	stdev
# R^2	0.55	0.02
# RMSE	14.25	0.27
#
# CatBoost Regression:
#
# Average performance of test set at 10 split
# Metric	avg	stdev
# R^2	0.57	0.04
# RMSE	13.87	0.66
#
# Statistics for the training set with 5CV catBoost:
#
# Average performance of 5CV
# Metric	avg	stdev
# R^2	0.56	0.02
# RMSE	14.14	0.18
#
# Product Strategy with Random Forest Regression:
#
# Average performance of test set at 10 split
# Metric	avg	stdev
# R^2	0.54	0.06
# RMSE	14.26	0.99
#
# Product Strategy with Statistics for the training set with 5CV RFR:
# R^2 =  0.57
# RMSE =  14.14
#
# Product Strategy with CatBoost Regression:
#
# Average performance of test set at 10 split
# Metric	avg	stdev
# R^2	0.54	0.06
# RMSE	14.18	1.05
#
# Product Strategy with Statistics for the training set with 5CV catBoost:
# R^2 =  0.56
# RMSE =  14.2
